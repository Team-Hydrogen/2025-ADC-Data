# %%
# !pip3 install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

nominaldf = pd.read_csv('./data/starting_data/hsdata.csv')
offdf = pd.read_csv('./data/starting_data/bonusdata.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       4 nominaldf = pd.read_csv('./data/starting_data/hsdata.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
offdf["DX (km)"] = offdf["Rx(km)[J2000-EARTH]"]-nominaldf["Rx(km)[J2000-EARTH]"]
offdf["DY (km)"] = offdf["Ry(km)[J2000-EARTH]"]-nominaldf["Ry(km)[J2000-EARTH]"]
offdf["DZ (km)"] = offdf["Rz(km)[J2000-EARTH]"]-nominaldf["Rz(km)[J2000-EARTH]"]
offdf.head()
# Out:
#    MISSION ELAPSED TIME (min)  Rx(km)[J2000-EARTH]  Ry(km)[J2000-EARTH]  \
# 0                    0.000000          3689.773564          4222.722170
# 1                    8.236481          2319.817224          4865.712767
# 2                    9.236481          1865.808701          4981.749611
# 3                   10.236481          1402.384261          5072.667625
# 4                   11.236481           932.010471          5138.480400
#
#    Rz(km)[J2000-EARTH]  Vx(km/s)[J2000-EARTH]  Vy(km/s)[J2000-EARTH]  \
# 0          3028.891599              -0.307917               0.268539
# 1          3698.167005              -7.474524               2.142613
# 2          3862.256016              -7.652172               1.724828
# 3          4006.812686              -7.788451               1.305814
# 4          4131.480818              -7.883949               0.888450
#
#    Vz(km/s)[J2000-EARTH]    MASS (kg)  EARTH Rx(km)[J2000-EARTH]  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

offdf.fillna(0, inplace=True)

X=offdf[["Rx(km)[J2000-EARTH]","Ry(km)[J2000-EARTH]","Rz(km)[J2000-EARTH]","Vx(km/s)[J2000-EARTH]","Vy(km/s)[J2000-EARTH]","Vz(km/s)[J2000-EARTH]"]]
Y=offdf[["DX (km)","DY (km)","DZ (km)"]]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

model = RandomForestRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9970961749220738

# %%
time = 60

thrust=[]
for i in range(offdf.shape[0]):
    x = offdf.iloc[i][["Rx(km)[J2000-EARTH]","Ry(km)[J2000-EARTH]","Rz(km)[J2000-EARTH]","Vx(km/s)[J2000-EARTH]","Vy(km/s)[J2000-EARTH]","Vz(km/s)[J2000-EARTH]"]].values
    mass = offdf.iloc[i]["MASS (kg)"]
    dx,dy,dz = model.predict([x])[0]
    thrust.append([mass*dx/(time**2),mass*dy/(time**2),mass*dz/(time**2)])

offdf["ThrustX (N)"] = [x[0] for x in thrust]
offdf["ThrustY (N)"] = [x[1] for x in thrust]
offdf["ThrustZ (N)"] = [x[2] for x in thrust]
offdf.head()
# Out:
# /home/vigneshaj/Vignesha/yw_vignesha/nasa_adc_2025/datavenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/vigneshaj/Vignesha/yw_vignesha/nasa_adc_2025/datavenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/vigneshaj/Vignesha/yw_vignesha/nasa_adc_2025/datavenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /home/vigneshaj/Vignesha/yw_vignesha/nasa_adc_2025/datavenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(offdf["ThrustX (N)"], offdf["ThrustY (N)"], offdf["ThrustZ (N)"], label='Thrust Vector', color='blue')
ax.set_xlabel('Thrust X (N)')
ax.set_ylabel('Thurst Y (N)')
ax.set_zlabel('Thrust Z (N)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
#       3 ax.plot(offdf["ThrustX (N)"], offdf["ThrustY (N)"], offdf["ThrustZ (N)"], label='Thrust Vector', color='blue')
#
# NameError: name 'plt' is not defined

# %%
#export
offdf.to_csv('./data/starting_data/thrustdata.csv', index=False)
